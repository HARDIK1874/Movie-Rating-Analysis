# %% [markdown]
# # 🎬 Movie Rating Analysis
#
# This project analyzes a dataset of movie ratings to uncover trends, insights, and potentially build predictive models. Let's explore how various features influence movie ratings.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 📥 Loading & Inspecting the Data
# We begin by loading the dataset and taking a first look at the structure.

# %%
movie = pd.read_csv('/content/Movie-Rating.csv')

# %% [markdown]
# ## 🧹 Data Cleaning
# This section focuses on checking for missing values, handling duplicates, and preparing the data for analysis.

# %%
movie
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movie)
# Out:
# pandas.core.frame.DataFrame

# %%
len(movie)
# Out:
# 559

# %%
np.__version__
# Out:
# '2.0.2'

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %% [markdown]
# ## 📊 Exploratory Data Analysis (EDA)
# We analyze various features such as genre, duration, rating distributions, and relationships between variables.

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movie.shape
# Out:
# (559, 6)

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.coulmns = ['Film', 'Genre', 'Critic Rating', 'Audience Ratings ','BudgetMillions', 'Year']
# Out:
# <ipython-input-17-40df753334c7>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   movie.coulmns = ['Film', 'Genre', 'Critic Rating', 'Audience Ratings ','BudgetMillions', 'Year']

# %%
movie.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movie.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.Film = movie.Film.astype('category')

# %%
movie.Genre = movie.Genre.astype('category')

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    category
#  1   Genre                      559 non-null    category
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movie.isna()
# Out:
#       Film  Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0    False  False                      False               False
# 1    False  False                      False               False
# 2    False  False                      False               False
# 3    False  False                      False               False
# 4    False  False                      False               False
# ..     ...    ...                        ...                 ...
# 554  False  False                      False               False
# 555  False  False                      False               False
# 556  False  False                      False               False
# 557  False  False                      False               False
# 558  False  False                      False               False
#
#      Budget (million $)  Year of release
# 0                 False            False
# 1                 False            False
# 2                 False            False
# ...

# %%
movie.isna().sum()
# Out:
# Film                         0
# Genre                        0
# Rotten Tomatoes Ratings %    0
# Audience Ratings %           0
# Budget (million $)           0
# Year of release              0
# dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
j = sns.jointplot(x = 'Rotten Tomatoes Ratings %', y = 'Audience Ratings %', data = movie, kind='hex')

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movie.columns = ['Film', 'Genre', 'Critic Rating', 'Audience Ratings', 'BudgetMillions', 'Year']

# %% [markdown]
# ## 🚀 Advanced Analysis Ideas
# We can enhance this project further with the following:

# %% [markdown]
# ### 🔧 Suggestions:
# - **Top-rated movies by genre/director/actor**
# - **Genre popularity over time**
# - **Correlation heatmaps of numeric features**
# - **Build a simple ML model to predict ratings**
# - **Create a basic recommendation system (collaborative or content-based)**

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Critic Rating', 'Audience Ratings', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
j1 = sns.jointplot(x = 'Critic Rating', y = 'Audience Ratings',data=movie)

# %%
m1 = sns.distplot(movie['Critic Rating'])

# %%
m2 = sns.displot(movie['Audience Ratings'])

# %%
sns.set_style('darkgrid') # white,dark,ticks,whitegrid,darkgrid

# %%
m2 = sns.displot(movie['Audience Ratings'], bins = 15)

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Critic Rating', 'Audience Ratings', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
plt.hist(movie.BudgetMillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
m3 = sns.lmplot(x = 'Critic Rating', y = 'Audience Ratings', fit_reg = True,data=movie)

# %%
m3 = sns.lmplot(x = 'Critic Rating', y = 'Audience Ratings', fit_reg = False, data=movie)

# %%
m3 = sns.lmplot(x = 'Critic Rating', y = 'Audience Ratings', fit_reg = True, data=movie, hue = 'Genre')

# %%
m4 = plt.subplots(1,2 , figsize = (10,5)) # 1, row and 2,column

# %%
movie
# Out:
#                       Film      Genre  Critic Rating  Audience Ratings  \
# 0    (500) Days of Summer      Comedy             87                81
# 1              10,000 B.C.  Adventure              9                44
# 2               12 Rounds      Action             30                52
# 3                127 Hours  Adventure             93                84
# 4                17 Again      Comedy             55                70
# ..                     ...        ...            ...               ...
# 554          Your Highness     Comedy             26                36
# 555        Youth in Revolt     Comedy             68                52
# 556                 Zodiac   Thriller             89                73
# 557            Zombieland      Action             90                87
# 558              Zookeeper     Comedy             14                42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# ...

# %%
m5 = sns.boxplot(x = 'Genre', y = 'Critic Rating', data = movie, hue='Genre')

# %%
m6 = sns.violinplot(x = 'Genre', y = 'Critic Rating', data = movie, hue = 'Genre')

# %%
movie.columns
# Out:
# Index(['Film', 'Genre', 'Critic Rating', 'Audience Ratings', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
m7 = sns.boxplot(data=movie[movie.Genre == 'Drama'],x= 'Year', y ='Audience Ratings') # Graph for individual attributes

# %%
m7 = sns.boxplot(data=movie[movie.Genre == 'Action'],x= 'Year', y ='Audience Ratings') # Graph for individual attributes

# %%
movie.head()
# Out:
#                     Film      Genre  Critic Rating  Audience Ratings  \
# 0  (500) Days of Summer      Comedy             87                81
# 1            10,000 B.C.  Adventure              9                44
# 2             12 Rounds      Action             30                52
# 3              127 Hours  Adventure             93                84
# 4              17 Again      Comedy             55                70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
g = sns.FacetGrid (data=movie, row = 'Genre', col = 'Year', hue = 'Genre') # used to create subset of the data

# %%
g = sns.FacetGrid (data=movie, row = 'Genre', col = 'Year', hue = 'Genre') # used to create subset of the data
g = g.map(sns.scatterplot, 'Critic Rating', 'Audience Ratings' ) #points are mapped in facetgrid and x-aixs = Cricticraying & y-axis = Audiencerating

# %%
g2 =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
g2 = g2.map(plt.hist, 'BudgetMillions')  # .MAP function maps the histplot in the facetgrid

# %%
g3 =sns.FacetGrid (movie, row = 'Genre', col = 'Year', hue = 'Genre')
kws = dict(s=60, linewidth=1.5,edgecolor='black')
# here s is size of the dots in the graph , linewidth is dimensu-ion the line around that dot , edge color is color of that line
g3 = g3.map(plt.scatter, 'Critic Rating', 'Audience Ratings',**kws )

# %% [markdown]
# ## ✅ Conclusion & Next Steps
# This project provided insights into movie ratings. Future work could involve machine learning models, time-series trend analysis, or user-based recommendation engines.
